# %% [markdown]
# ## 線形回帰サンプル

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

num = 10 # sample point num

# 乱数で生成
x = np.random.rand(num).reshape(num,1)
y = np.random.rand(num)

# 線形回帰モデル
model = LinearRegression()

# 学習
model.fit(x,y)

print("y = " + str(model.intercept_) + " + " + str(model.coef_[0])  + "x")

x_test = [[0],[1]]
y_pred = model.predict(x_test)

# プロット
plt.scatter(x,y)
plt.plot(x_test, y_pred)
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# y = -0.027459166404482482 + 0.6689735656843898x
